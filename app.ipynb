# %%
import logging

logging.basicConfig(filename="test2.log",
                    level=logging.DEBUG,
                    format='%(levelname)s %(asctime)s %(message)s',
                    datefmt='%Y-%m-%d %H:%M:%S')
logging.info("this is logging")
l = [1, 2, 3, 4, 5, 0]
for i in l:
    logging.info("we are inside the loop")
    if i == 2:  # Compare with integer 2 instead of string "2"
        logging.info(l)
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "c:\ProgramData\anaconda3\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: 'level'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\lib\logging\__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "c:\ProgramData\anaconda3\lib\logging\__init__.py", line 943, in format
#     return fmt.format(record)
#   File "c:\ProgramData\anaconda3\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "c:\ProgramData\anaconda3\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "c:\ProgramData\anaconda3\lib\logging\__init__.py", line 442, in format
# ...

# %%
num =int(input("give you input"))
for i in num:
    def cube(a):
        logging.info("we are inside the the cube function")
        return a**3
        logging.info("cube of %s is", a)
    
    cube(1)
    i = i+1
    if i <=5:
        break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 num =int(input("give you input"))
# ----> 2 for i in num:
#       3     def cube(a):
#       4         logging.info("we are inside the the cube function")
#
# TypeError: 'int' object is not iterable

# %%
###Ques2:
import logging
logging.basicConfig(filename="test2.log", level=logging.DEBUG,)
logging.debug("debugging started")


def cube(i):
              logging.debug("we are inside the cube function")
              logging.debug("cube of %s is", cube)
              logging.debug(i)
              return i**3
def sqr(a):
       logging.debug("inside sqr fx")
       logging.debug("%s",a)
       return a**2

#result= int(input("give yout numbr: "))
logging.debug("cube of %s",cube)
cube(5)
logging.debug('cube of %s',cube)
logging.debug("sqr of %s",sqr)
sqr(5)
# Out:
# 125

# %%
for i in range(5):
    print((cube(i), sqr(5)), end=" ")
# Out:
# (0, 25) (1, 25) (8, 25) (27, 25) (64, 25)

# %% [markdown]
# Ques 3

# %%
import logging
logging.basicConfig(filename="test2.log",
                    level=logging.DEBUG,
                    format='%(levelname)s %(name)s %(asctime)s %(message)s')
logging.debug("Pre level1")
def div(a,b):
        return a/b
try:
    logging.debug("entering TRY fx")
    number1 = int(input("you 1st number: "))
    number2 = int(input("give your 2nd number: "))
    logging.debug("both the numbers are input")
    print(number1/number2)
    logging.info("result of %s %s",number1,number2)
except Exception:
    print("you did someting wrong")
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "c:\ProgramData\anaconda3\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: 'level'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\lib\logging\__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "c:\ProgramData\anaconda3\lib\logging\__init__.py", line 943, in format
#     return fmt.format(record)
#   File "c:\ProgramData\anaconda3\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "c:\ProgramData\anaconda3\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "c:\ProgramData\anaconda3\lib\logging\__init__.py", line 442, in format
# ...
